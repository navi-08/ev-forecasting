# %%
import pandas as pd
from pathlib import Path

stock_data_to_load = Path("Resources/symbols_valid_meta.csv")

stock_data = pd.read_csv(stock_data_to_load)

# %%
tsla_dtl = Path("Resources/TSLA.csv")
tm_dtl = Path("Resources/TM.csv")
race_dtl = Path("Resources/RACE.csv")
hmc_dtl = Path("Resources/HMC.csv")
f_dtl = Path("Resources/F.csv")
gm_dtl = Path("Resources/GM.csv")
nio_dtl = Path("Resources/NIO.csv")
pii_dtl = Path("Resources/PII.csv")
kndi_dtl = Path("Resources/KNDI.csv")
solo_dtl = Path("Resources/SOLO.csv")
fuv_dtl = Path("Resources/FUV.csv")


tsla_df = pd.read_csv(tsla_dtl)
tm_df = pd.read_csv(tm_dtl)
race_df = pd.read_csv(race_dtl)
hmc_df = pd.read_csv(hmc_dtl)
f_df = pd.read_csv(f_dtl)
gm_df = pd.read_csv(gm_dtl)
nio_df = pd.read_csv(nio_dtl)
pii_df = pd.read_csv(pii_dtl)
kndi_df = pd.read_csv(kndi_dtl)
solo_df = pd.read_csv(solo_dtl)
fuv_df = pd.read_csv(fuv_dtl)

# %%
auto_stocks_dict = {'Telsa':'TSLA',
                   'Toyota':'TM',
                   'Ferrari':'RACE',
                    'Honda':'HMC',
                    'Ford': 'F',
                    'General Motors': 'GM',
                    'NIO': 'NIO',
                    'Polaris': 'PII',
                    'Kandi Technologies Group': 'KNDI',
                    'Electra Meccanica': 'SOLO',
                    'Arcimoto': 'FUV',
                   }

tickers = [val for val in auto_stocks_dict.values()]

# %%
automotive_df = stock_data[stock_data['Symbol'].isin(tickers)]
automotive_df
# Out:
#      Nasdaq Traded Symbol                                      Security Name  \
# 2433             Y      F                    Ford Motor Company Common Stock
# 2859             Y    FUV                      Arcimoto, Inc. - Common Stock
# 3051             Y     GM                General Motors Company Common Stock
# 3368             Y    HMC             Honda Motor Company, Ltd. Common Stock
# 4176             Y   KNDI      Kandi Technologies Group, Inc. - Common Stock
# 5012             Y    NIO  NIO Inc. American depositary shares, each  rep...
# 5598             Y    PII                          Polaris Inc. Common Stock
# 5958             Y   RACE                         Ferrari N.V. Common Shares
# 6644             Y   SOLO  Electrameccanica Vehicles Corp. Ltd. - Common ...
# 7096             Y     TM              Toyota Motor Corporation Common Stock
# 7208             Y   TSLA                        Tesla, Inc.  - Common Stock
#
#      Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 2433                N                   N           100.0          N
# 2859                Q               S   N           100.0          N
# 3051                N                   N           100.0          N
# 3368                N                   N           100.0          N
# 4176                Q               Q   N           100.0          N
# 5012                N                   N           100.0          N
# 5598                N                   N           100.0          N
# 5958                N                   N           100.0          N
# 6644                Q               S   N           100.0          N
# 7096                N                   N           100.0          N
# 7208                Q               Q   N           100.0          N
#
#      Financial Status CQS Symbol NASDAQ Symbol NextShares
# 2433              NaN          F             F          N
# 2859                D        NaN           FUV          N
# 3051              NaN         GM            GM          N
# 3368              NaN        HMC           HMC          N
# 4176                N        NaN          KNDI          N
# 5012              NaN        NIO           NIO          N
# 5598              NaN        PII           PII          N
# 5958              NaN       RACE          RACE          N
# 6644                N        NaN          SOLO          N
# 7096              NaN         TM            TM          N
# 7208                N        NaN          TSLA          N

# %%
ticker_symbol = 'FFIE'
matching_rows = stock_data[stock_data['Symbol'] == ticker_symbol]
matching_rows
# Out:
# Empty DataFrame
# Columns: [Nasdaq Traded, Symbol, Security Name, Listing Exchange, Market Category, ETF, Round Lot Size, Test Issue, Financial Status, CQS Symbol, NASDAQ Symbol, NextShares]
# Index: []

# %%
tsla_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2452  2020-03-26  547.390015  560.000000  512.250000  528.159973  528.159973
# 2453  2020-03-27  505.000000  525.799988  494.029999  514.359985  514.359985
# 2454  2020-03-30  510.260010  516.650024  491.230011  502.130005  502.130005
# 2455  2020-03-31  501.250000  542.960022  497.000000  524.000000  524.000000
# 2456  2020-04-01  504.000000  513.950012  475.100006  481.559998  481.559998
#
#         Volume
# 0     18766300
# 1     17187100
# 2      8218800
# 3      5139800
# 4      6866900
# ...        ...
# 2452  17380700
# 2453  14377400
# 2454  11998100
# 2455  17771500
# 2456  13304500
#
# [2457 rows x 7 columns]

# %%
#to convert to monthly data if needed

tsla_df['Date'] = pd.to_datetime(tsla_df['Date'])

tsla_df['year_month'] = tsla_df['Date'].dt.to_period('M')

last_day_of_month = tsla_df.groupby('year_month')['Date'].max()

filtered_tsla = tsla_df[tsla_df['Date'].isin(last_day_of_month)]

filtered_tsla.drop(columns=['year_month'], inplace=True)

filtered_tsla
# Out:
# /var/folders/b2/z189kxj141d27kr4q23f5glc0000gn/T/ipykernel_96951/679508512.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_tsla.drop(columns=['year_month'], inplace=True)
#            Date        Open        High         Low       Close   Adj Close  \
# 1    2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 22   2010-07-30   20.200001   20.440001   19.549999   19.940001   19.940001
# 44   2010-08-31   19.660000   19.790001   19.330000   19.480000   19.480000
# 65   2010-09-30   22.000000   22.150000   20.190001   20.410000   20.410000
# 86   2010-10-29   21.139999   21.850000   21.049999   21.840000   21.840000
# ...         ...         ...         ...         ...         ...         ...
# 2393 2019-12-31  405.000000  421.290009  402.079987  418.329987  418.329987
# 2414 2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2433 2020-02-28  629.700012  690.520020  611.520020  667.989990  667.989990
# 2455 2020-03-31  501.250000  542.960022  497.000000  524.000000  524.000000
# 2456 2020-04-01  504.000000  513.950012  475.100006  481.559998  481.559998
#
#         Volume
# 1     17187100
# 22      426900
# 44      201100
# 65     2195800
# 86      280600
# ...        ...
# 2393  10285700
# 2414  15719300
# 2433  24564200
# 2455  17771500
# 2456  13304500
#
# [119 rows x 7 columns]

# %%
dataframes = []

for company, ticker in auto_stocks_dict.items():
    df_name = ticker.lower() + '_df'
    dataframes.append(df_name)

tickers = list(auto_stocks_dict.values())
print(tickers)
# Out:
# ['TSLA', 'TM', 'RACE', 'HMC', 'F', 'GM', 'NIO', 'PII', 'KNDI', 'SOLO', 'FUV']

# %%
print(dataframes)
# Out:
# ['tsla_df', 'tm_df', 'race_df', 'hmc_df', 'f_df', 'gm_df', 'nio_df', 'pii_df', 'kndi_df', 'solo_df', 'fuv_df']

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 3
#       1 for df in dataframes:
#       2     # Extract the ticker symbol from the dataframe's variable name
# ----> 3     ticker = df.columns[0].split('_')[0]
#       5     # Change the header "Close" to the ticker symbol
#       6     df.rename(columns={'Close': ticker}, inplace=True)
#
# AttributeError: 'str' object has no attribute 'columns'
